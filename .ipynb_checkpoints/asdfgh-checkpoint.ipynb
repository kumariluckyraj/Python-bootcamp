# %%
"hello world"
# Out:
# 'hello world'

# %%
import matplotlib.pyplot as plt


import numpy as np
x=np.arange(0,10)
y=np.arange(11,21)
plt.scatter(x,y,c='g')
plt.xlabel('hehe')
plt.ylabel('haha')
plt.title('test')
plt.savefig('Test.png')
plt.show()
